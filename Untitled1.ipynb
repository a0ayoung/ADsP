# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv("C:/Users/Administrator/Desktop/BigData/class/suicide_GG.csv")

# %%
df.head()
# Out:
#    sex  year  month  d_date  time  age  job  marriage  edu
# 0    2  2016     10      18    20  109   13         4    1
# 1    2  2014     10      28     8  103   13         4    1
# 2    2  2015      3      15    23  101   13         4    1
# 3    1  2016     11      21    17  100   13         4    2
# 4    2  2016      9      24    17  100   13         4    1

# %%
pd.scatter_matrix(df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000A54250B198>,
# ...
#       dtype=object)

# %%
pd.scatter_matrix(df[['sex', 'month', 'marriage']],)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000A544778748>,
# ...
#       dtype=object)

# %%
df[['d_date','time']].plot()

# %%
df.year.value_counts().sort_index(ascending=False).head()
# Out:
# 2016    2879
# 2015    3123
# 2014    3139
# Name: year, dtype: int64

# %%
age_count  = df.age.value_counts()
age_count.head()
# Out:
# 54    234
# 46    226
# 44    219
# 52    213
# 50    210
# Name: age, dtype: int64

# %%
df.age.value_counts().sort_index().plot()

# %%
df.year.value_counts().sort_index().plot()

# %%
df.year.plot(kind='hist', bins = 100)

# %%
df.edu.value_counts().sort_index(ascending=False)
# Out:
# 9     295
# 7     203
# 6    1987
# 4    3554
# 3    1268
# 2    1360
# 1     474
# Name: edu, dtype: int64

# %%
df.edu.plot(kind='hist', bins = 100)

# %%
df.groupby('month').mean()
# Out:
#             sex         year     d_date       time        age        job  \
# month
# 1      1.285928  2014.941617  15.552395  12.754491  52.670659  12.441617
# 2      1.298720  2014.981508  14.798009  13.145092  51.203414  11.870555
# 3      1.293660  2014.929922  16.196885  12.879867  52.189099  12.767519
# 4      1.295742  2014.927503  16.018412  12.821634  52.998849  12.225547
# 5      1.280460  2014.926437  16.056322  12.262069  50.822989  12.747126
# 6      1.284585  2014.986825  15.321476  12.268775  52.532279  12.598155
# 7      1.322825  2014.967213  15.282472  11.963430  51.976040  12.476671
# 8      1.328662  2015.008917  15.686624  12.267516  52.831847  13.345223
# 9      1.301120  2015.025210  15.309524  12.637255  53.336134  13.229692
# 10     1.284585  2015.031621  15.903821  12.870883  53.035573  13.073781
# 11     1.313456  2014.977064  15.048930  12.677370  52.495413  12.259939
# 12     1.294910  2014.976048  16.196108  13.238024  51.236527  13.047904
#
# ...

# %%
df.groupby('month')['time', 'age'].mean().plot()

# %%
df.groupby('month')['time'].mean().plot()

# %%
df.age.plot(kind = 'hist', bins = 10)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv("C:/Users/Administrator/Desktop/BigData/class/Suicide edit Ara.csv")

# %%
df_M=df.query('sex == 1')
df_M
# Out:
#        time  sex  year  month  d_date  age  job  marriage  edu  temp  rain  \
# 1         8    1  2014      1       1   29    4         3    4   0.5   0.0
# 2         8    1  2014      1       1   73    4         2    4   0.5   0.0
# 3         9    1  2014      1       1   26    9         1    5   1.8   0.0
# 6        12    1  2014      1       1   47    9         1    4   7.0   0.0
# 7        12    1  2014      1       1   79    9         2    4   7.0   0.0
# 8        13    1  2014      1       1   51    9         3    2   6.7   0.0
# 9        14    1  2014      1       1   45    9         3    4   7.1   0.0
# 10       15    1  2014      1       1   69    4         2    2   7.6   0.0
# 11       17    1  2014      1       1   85    9         4    2   6.6   0.0
# 12       18    1  2014      1       1   48    2         3    5   6.1   0.0
# 14        3    1  2014      1       2   38    9         1    5   0.3   0.0
# ...

# %%
df_W=df.query('sex == 2')
df_W
# Out:
#        time  sex  year  month  d_date  age  job  marriage  edu  temp  rain  \
# 0         7    2  2014      1       1   23    9         1    5   0.7   0.0
# 4        11    2  2014      1       1   76    9         4    1   5.4   0.0
# 5        11    2  2014      1       1   29    2         2    6   5.4   0.0
# 13       22    2  2014      1       1   38    9         2    5   4.3   0.0
# 15        5    2  2014      1       2   17    9         1    4  -0.5   0.0
# 16        7    2  2014      1       2   54    9         3    2  -1.1   0.0
# 17        8    2  2014      1       2   94    9         4    1  -1.2   0.0
# 21       14    2  2014      1       2   48    4         3    4   5.5   0.0
# 22       14    2  2014      1       2   74    9         2    5   5.5   0.0
# 27       19    2  2014      1       2   41    2         1    5   2.7   0.0
# 28       20    2  2014      1       2   34    9         3    4   1.5   0.0
# ...

# %%
df_M.time.value_counts().sort_index().plot()

# %%
df_W.time.value_counts().sort_index().plot()

# %%
df_M.temp.value_counts().sort_index().plot()

# %%
a = df_W.groupby('month')['time'].value_counts().sort_index().plot()
a

# %%
df_W_Jan=df_W.query('month == 1')

# %%
df_W_Jan.temp.value_counts().sort_index().plot(kind='bar', figsize = (20, 15))

# %%
df_M_Jan=df_M.query('month == 1')

# %%
df_W_Feb=df_W.query('month == 2')

# %%
df_W_Jan.temp.mean()
# Out:
# -1.114824797843666

# %%
df_M_Jan.temp.value_counts().sort_index().plot(kind='bar', figsize = (20, 15))

# %%
df_W_Feb.temp.value_counts().sort_index().plot(kind='bar', figsize = (10, 2))

# %%
df_M_Feb=df_M.query('month == 2')

# %%
df_M_Feb.temp.value_counts().sort_index().plot(kind='bar', figsize = (10, 2))

# %%
df_M_Aug=df_M.query('month == 8')

# %%
df_M_Aug.temp.value_counts().sort_index().plot(kind='bar', figsize = (100, 100))

# %%
df_M_Aug.temp.mean()
# Out:
# 26.795995670995655

# %%
df_2014=df_M.query('year == 2014')

# %%
df_W_Aug=df_W.query('month == 8')

# %%
df_W_Aug.temp.mean()
# Out:
# 26.579138321995444

# %%
df_Aug=df.query('month == 8')

# %%
df_Aug.temp.mean()
# Out:
# 26.725934065934055

# %%
df_Jan=df.query('month == 1')

# %%
df_Jan.temp.mean()
# Out:
# -1.004294975688816

# %%
df_elder=df.query('age >=  65')

# %%
df_elder.month.value_counts().sort_index().plot(kind = 'bar')

# %%
df.month.value_counts().sort_index().plot()

# %%
df_elder_Aug=df_elder.query('month == 8')

# %%
df_elder_Aug.mean()
# Out:
# time            11.518041
# sex              1.378866
# year          2015.023196
# month            8.000000
# d_date          15.695876
# age             76.224227
# job              8.523196
# marriage         2.840206
# edu              2.889175
# temp            26.681443
# rain             0.176804
# humidity        69.701031
# cloud            5.402062
# clim_num    376351.332474
# snow             0.000000
# sun              0.289691
# dtype: float64

# %%
b = df.groupby('year').va

# %%
b.month.value_counts().sort_index()
# Out:
# year  month
# 2014  1        424
#       2        431
#       3        618
#       4        557
#       5        520
#       6        456
#       7        492
#       8        449
#       9        448
#       10       414
#       11       422
#       12       376
# 2015  1        434
#       2        411
#       3        494
#       4        530
#       5        565
#       6        422
#       7        487
#       8        474
#       9        419
#       10       453
#       11       370
#       12       357
# 2016  1        376
#       2        383
#       3        479
#       4        468
#       5        485
#       6        437
#       7        421
#       8        442
#       9        440
#       10       450
#       11       377
#       12       382
# Name: month, dtype: int64

# %%
df_elder.to_csv('elder.csv', index = False)

# %%
df_normal=df.query('age <  65')

# %%
df_normal.to_csv('normal.csv', index = False)

# %%
c = b.groupby('month')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-d8f5cd2b612c> in <module>()
# ----> 1 c = b.groupby('month')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
#     801         self._set_group_selection()
#
# ...

# %%
df_M.job.value_counts().plot(kind = 'bar')
